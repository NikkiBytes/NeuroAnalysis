# %%
import os, glob
from IPython.core import display as ICD
import pandas as pd

pd.set_option('display.max_rows', 159)
pd.set_option('display.max_colwidth', -1)

# %%
ana_folder_report = pd.read_csv("analysis_folder_report.tsv", sep="\t")
ana_folder_report.set_index('Unnamed: 0', inplace=True)
ana_folder_report.index.rename("subject",inplace=True)

# %% [markdown]
# ## File Report

# %%
ana_folder_report
# Out:
#             anat    funcs confounds    mocos   onsets
# subject
# sub-001  good     5        5         30       28
# sub-002  good     5        2         30       28
# sub-003  good     5        5         30       28
# sub-004  good     5        5         30       28
# sub-005  good     5        5         30       28
# sub-006  good     5        5         30       28
# sub-007  good     5        5         30       28
# sub-008  good     5        5         30       28
# sub-009  good     5        5         30       28
# sub-010  good     5        5         30       28
# sub-011  good     5        5         30       28
# sub-012  good     5        5         30       28
# sub-013  good     5        missing   30       28
# sub-014  good     5        5         30       28
# sub-015  good     5        5         30       28
# sub-016  good     5        1         30       28
# sub-017  good     5        4         30       28
# sub-018  good     5        5         30       28
# ...
